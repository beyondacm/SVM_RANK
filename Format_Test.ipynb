# %%
import pandas as pd
import numpy as np
import operator
import re

# %%
Total_Train = pd.read_csv('./Total.csv')
Total_Test = pd.read_csv('./Total_Test.csv')

# %%
def Get_Index_QuestionID(qid, DataSet) :
    return DataSet[ DataSet['question_id'] == qid].index.values[0]

# %%
def Get_Index_List(Qid_List, DataSet) :
    Index_List = []
    for qid in Qid_List :
        print qid
        index = Get_Index_QuestionID(qid, DataSet)
        A0_Index_List.append(index)

# %%
Q0_Similar_List = [1025005, 6646280, 356498, 1011149, 676136, 563166, 1170863, 764736, 6713486, 1450862, \
                   1246057, 489524, 813961, 6759143, 563931, 362844, 1452359, 768780, 6658452, 1356635]

# %%
Q1_Similar_List = [1184609, 1229655, 1510461, 1606095, 1414194, 1354179, 1575349, 944467, 1434648, 676013, \
                   961331, 6612509, 1272697, 1492324, 521359, 1179128, 1487179, 6649311, 1289121, 1038600]

# %%
Q2_Similar_List = [1163976, 1087689, 1522753, 1174526, 1481746, 1068081, 6700922, 842804, 1290109, 1156334, \
                   6698482, 1440394, 60032, 1453499, 1059922, 1190420, 1455815, 1522681, 1364135, 1033400]

# %%
Q0_Index_List = Get_Index_List(Q0_Similar_List, Total_Test)
Q1_Index_List = Get_Index_List(Q1_Similar_List, Total_Test)
Q2_Index_List = Get_Index_List(Q2_Similar_List, Total_Test)
# Out:
# 1025005
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-46-4481ae156ecc> in <module>()
# ----> 1 Q0_Index_List = Get_Index_List(Q0_Similar_List, Total_Test)
#       2 Q1_Index_List = Get_Index_List(Q1_Similar_List, Total_Test)
#       3 Q2_Index_List = Get_Index_List(Q2_Similar_List, Total_Test)
#
# <ipython-input-42-a5d5f49da26b> in Get_Index_List(Qid_List, DataSet)
#       3     for qid in Qid_List :
#       4         print qid
# ----> 5         index = Get_Index_QuestionID(qid, DataSet)
#       6         A0_Index_List.append(index)
#
# <ipython-input-31-eb146fa868f9> in Get_Index_QuestionID(qid, DataSet)
#       1 def Get_Index_QuestionID(qid, DataSet) :
# ----> 2     return DataSet[ DataSet['question_id'] == qid].index.values[0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
Total_Test[ Total_Test['question_id'] == 1025005].index
# Out:
# Int64Index([], dtype='int64')

# %%
Total_Test
# Out:
#                                           answer_content answer_id  \
# 0      yes a replaced knee is often more swollen than...   1433245
# 1      yes it takes several months but eventually swe...   1430995
# 2      unlikely it is very unlikely that only symptom...   1515830
# 3      stop diet pills during your recovery from surg...   1463380
# 4      not really these are both antihistamines if bo...   1486787
# 5      claritin hello  i have treated many people wit...   1435962
# 6      all possible if you think you may be pregnant ...   1428983
# 7      14 days most chlamydia infections do not cause...   1469376
# 8      if you are sexually active this would be a goo...   1461831
# 9      individual variance any medication can produce...   1688561
# 10     possible infection you may be dealing with hor...   1454843
# 11     could be lymph nodes are all over the body you...    176101
# 12     simply monitoring lymphatic system absorbs car...   1517663
# ...

# %%
Total_Test[ Total_Test['question_id'] == int(6646280) ]
# Out:
# Empty DataFrame
# Columns: [answer_content, answer_id, answer_voted, question_id, user_id, user_agrees, user_edu, user_exp, user_followed, user_helped, user_interest, user_intro, user_recommends, user_saved, user_specialty, user_thanks, question_tags, question_content]
# Index: []
